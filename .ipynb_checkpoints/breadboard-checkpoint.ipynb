# %%
import numpy as np
from tqdm.notebook import tqdm
import time
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
from matplotlib.patches import RegularPolygon
from scipy.spatial.distance import cdist
from IPython.display import HTML
import itertools
import time
import matplotlib.cm as cm
from copy import deepcopy
from importlib import reload
import patahistory as p
from matplotlib import animation
import itertools
import time
reload(p);

# %%
tic = time.time()
grid = p.Grid(35, wraparound=True)
toc1 = time.time()
grid.land_and_water(land_coef=.50)
toc2 = time.time()
p.draw_map(grid)
toc3 = time.time()

# %%
print(f'Generating the grid took {toc1 - tic}.')
print(f'Generating the land took {toc2 - toc1}.')
print(f'Generating the map took {toc3 - toc2}.')
# Out:
# Generating the grid took 0.16843891143798828.
# Generating the land took 1.5144364833831787.
# Generating the map took 1.0952672958374023.

# %%
print(f'Generating the grid took {toc1 - tic}.')
print(f'Generating the land took {toc2 - toc1}.')
print(f'Generating the map took {toc3 - toc2}.')
# Out:
# Generating the grid took 0.16843891143798828.
# Generating the land took 1.5144364833831787.
# Generating the map took 1.0952672958374023.

# %%
tic = time.time()
grid = p.Grid(35)
toc1 = time.time()
grid.land_init(land_coef=.50)
toc2 = time.time()
p.draw_map(grid)
toc3 = time.time()

# %%
def data_gen():
    for cnt in itertools.count():
        t = cnt / 10
        yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)


def init():
    ax.set_ylim(-1.1, 1.1)
    ax.set_xlim(0, 10)
    del xdata[:]
    del ydata[:]
    line.set_data(xdata, ydata)
    return line,

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.grid()
xdata, ydata = [], []


def run(data):
    # update the data
    t, y = data
    xdata.append(t)
    ydata.append(y)
    xmin, xmax = ax.get_xlim()

    if t >= xmax:
        ax.set_xlim(xmin, 2*xmax)
        ax.figure.canvas.draw()
    line.set_data(xdata, ydata)

    return line,

ani = animation.FuncAnimation(fig, run, data_gen, interval=10, init_func=init, blit=True)
ani.save('test.gif', writer='imagemagick', fps=60)
